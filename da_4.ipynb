# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\1492400551.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open("retail_sales_dataset.csv", "r", encoding='utf8') as file:
    file_csv = pd.read_csv(file)
    df = pd.DataFrame(file_csv)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
duplicate_rows = df.duplicated()
df['is_duplicated'] = df.duplicated()

# %%
df['Total Amount'] = df['Total Amount'].astype(float)

# %%
df["Age Category"] = pd.cut(df['Age'],
                      bins=[df['Age'].min()-1, 19, 39, 59, df['Age'].max()],
                      labels=['Teen', 'Adult', 'Middle Age Adult', 'Senior Adult'])

# %%
df['Age Category'].unique
# Out:
# <bound method Series.unique of 0                 Adult
# 1                 Adult
# 2      Middle Age Adult
# 3                 Adult
# 4                 Adult
#              ...
# 995        Senior Adult
# 996    Middle Age Adult
# 997               Adult
# 998               Adult
# 999    Middle Age Adult
# Name: Age Category, Length: 1000, dtype: category
# Categories (4, object): ['Teen' < 'Adult' < 'Middle Age Adult' < 'Senior Adult']>

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/30/d0/abcdb0669931be3a98881e6d7851605981693e93a7924061c67d0cd9f292/openpyxl-3.1.4-py2.py3-none-any.whl.metadata
#   Downloading openpyxl-3.1.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl.metadata
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.4-py2.py3-none-any.whl (251 kB)
#    ---------------------------------------- 0.0/251.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/251.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/251.4 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/251.4 kB 217.9 kB/s eta 0:00:02
#    ---- ---------------------------------- 30.7/251.4 kB 262.6 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/251.4 kB 393.8 kB/s eta 0:00:01
#    ---------------------------------------  245.8/251.4 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 251.4/251.4 kB 1.1 MB/s eta 0:00:00
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
(df.groupby(['Age Category'])['Total Amount'].sum()).to_excel("age_spentamount_dependency.xlsx")
(df.groupby(['Age Category'])['Total Amount'].sum()).plot.bar(width=0.7, color='green')
plt.xlabel('Age Category')
plt.ylabel('Total Amount')
plt.title('Adults spend more')
plt.grid(True)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\2136539649.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category'])['Total Amount'].sum()).to_excel("age_spentamount_dependency.xlsx")
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\2136539649.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category'])['Total Amount'].sum()).plot.bar(width=0.7, color='green')

# %%
(df.groupby(['Age Category'])['Transaction ID'].count()).plot.bar(width=0.7)
(df.groupby(['Age Category'])['Transaction ID'].count()).to_excel("age_ordercount_dependency.xlsx")
plt.xlabel('Age Category')
plt.ylabel('Placed order count')
plt.title('Middle Age Adults shop more often')
plt.grid(True)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\3200934476.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category'])['Transaction ID'].count()).plot.bar(width=0.7)
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\3200934476.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category'])['Transaction ID'].count()).to_excel("age_ordercount_dependency.xlsx")

# %%
df.groupby(['Gender'])['Total Amount'].sum()
# Out:
# Gender
# Female    232840.0
# Male      223160.0
# Name: Total Amount, dtype: float64

# %%
(df.groupby(['Gender'])['Total Amount'].sum()).plot.bar(width=0.7)
(df.groupby(['Gender'])['Total Amount'].sum()).to_excel("gender_spentamount_dependency.xlsx")
plt.show()

# %%
(df.groupby(['Gender'])['Transaction ID'].count()).plot.bar(width=0.7)
(df.groupby(['Gender'])['Transaction ID'].count()).to_excel("gender_ordercount_dependency.xlsx")

# %%
df.groupby(['Age Category','Gender'])['Total Amount'].sum()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\3306657135.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Age Category','Gender'])['Total Amount'].sum()
# Age Category      Gender
# Teen              Female    15275.0
#                   Male      10810.0
# Adult             Female    97495.0
#                   Male      95900.0
# Middle Age Adult  Female    98980.0
#                   Male      92725.0
# Senior Adult      Female    21090.0
#                   Male      23725.0
# Name: Total Amount, dtype: float64

# %%
(df.groupby(['Age Category','Gender'])['Total Amount'].sum()).plot.bar(width=0.7)
(df.groupby(['Age Category','Gender'])['Total Amount'].sum()).to_excel("age_gender_spentamount_dependency.xlsx")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\1092239166.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Gender'])['Total Amount'].sum()).plot.bar(width=0.7)
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\1092239166.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Gender'])['Total Amount'].sum()).to_excel("age_gender_spentamount_dependency.xlsx")

# %%
df.groupby(['Age Category','Gender'])['Transaction ID'].count()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\2001116280.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Age Category','Gender'])['Transaction ID'].count()
# Age Category      Gender
# Teen              Female     24
#                   Male       18
# Adult             Female    198
#                   Male      202
# Middle Age Adult  Female    233
#                   Male      210
# Senior Adult      Female     55
#                   Male       60
# Name: Transaction ID, dtype: int64

# %%
(df.groupby(['Age Category','Gender'])['Transaction ID'].count()).plot.bar(width=0.7)
(df.groupby(['Age Category','Gender'])['Transaction ID'].count()).to_excel("age_gender_ordercount_dependency.xlsx")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\2491821499.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Gender'])['Transaction ID'].count()).plot.bar(width=0.7)
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\2491821499.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Gender'])['Transaction ID'].count()).to_excel("age_gender_ordercount_dependency.xlsx")

# %%
(df.groupby(['Product Category'])['Total Amount'].sum()).plot.bar(width=0.7)
(df.groupby(['Product Category'])['Total Amount'].sum()).to_excel('product_category_price_distribution.xlsx')
plt.show()

# %%
(df.groupby(['Product Category'])['Transaction ID'].count()).plot.bar(width=0.7)
(df.groupby(['Product Category'])['Transaction ID'].count()).to_excel('product_category_sale_distribution.xlsx')
plt.show()

# %%
(df.groupby(['Product Category', 'Age Category'])['Total Amount'].sum()).to_excel('age_product_spentamount_dependency.xlsx')
(df.groupby(['Age Category', 'Product Category'])['Total Amount'].sum()).plot.bar(width=0.7)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\3978811672.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Product Category', 'Age Category'])['Total Amount'].sum()).to_excel('age_product_spentamount_dependency.xlsx')
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\3978811672.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category', 'Product Category'])['Total Amount'].sum()).plot.bar(width=0.7)

# %%
(df.groupby(['Product Category', 'Age Category'])['Transaction ID'].count()).to_excel('age__product_ordercount_dependency.xlsx')
(df.groupby(['Age Category','Product Category'])['Transaction ID'].count()).plot.bar(width=0.7)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\571808327.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Product Category', 'Age Category'])['Transaction ID'].count()).to_excel('age__product_ordercount_dependency.xlsx')
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\571808327.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Product Category'])['Transaction ID'].count()).plot.bar(width=0.7)

# %%
(df.groupby(['Product Category','Gender', 'Age Category'])['Total Amount'].sum()).to_excel('age_gender_product_spentamount_dependency.xlsx')
(df.groupby(['Age Category','Gender','Product Category'])['Total Amount'].sum()).plot.bar(width=0.7)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\404327532.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Product Category','Gender', 'Age Category'])['Total Amount'].sum()).to_excel('age_gender_product_spentamount_dependency.xlsx')
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\404327532.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Gender','Product Category'])['Total Amount'].sum()).plot.bar(width=0.7)

# %%
(df.groupby(['Product Category','Gender', 'Age Category'])['Transaction ID'].count()).to_excel('age_gender_product_ordercount_dependency.xlsx')
(df.groupby(['Age Category','Gender','Product Category'])['Transaction ID'].count()).plot.bar(width=0.7)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\4209603767.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Product Category','Gender', 'Age Category'])['Transaction ID'].count()).to_excel('age_gender_product_ordercount_dependency.xlsx')
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\4209603767.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df.groupby(['Age Category','Gender','Product Category'])['Transaction ID'].count()).plot.bar(width=0.7)

# %%
df['date_month'] = pd.to_datetime(df['Date'], format='mixed') - pd.to_timedelta(1, unit='m')
month = df.groupby([pd.Grouper(key='date_month', freq='M')])['Transaction ID'].count()
df.groupby([pd.Grouper(key='date_month', freq='M')])['Transaction ID'].count().to_excel('sales_count_monthly.xlsx')
df.groupby([pd.Grouper(key='date_month', freq='M')])['Total Amount'].sum().to_excel('sales_sum_monthly.xlsx')
df_month = pd.DataFrame({'Month': month.index, 'Count': month.values})
df_month.plot(kind = 'bar', x = 'Month', y = 'Count')
# print(df_month)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\4263735541.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   month = df.groupby([pd.Grouper(key='date_month', freq='M')])['Transaction ID'].count()
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\4263735541.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby([pd.Grouper(key='date_month', freq='M')])['Transaction ID'].count().to_excel('sales_count_monthly.xlsx')
# C:\Users\admin\AppData\Local\Temp\ipykernel_13428\4263735541.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby([pd.Grouper(key='date_month', freq='M')])['Total Amount'].sum().to_excel('sales_sum_monthly.xlsx')

# %%
df['date_week'] = pd.to_datetime(df['Date'], format='mixed') - pd.to_timedelta(7, unit='d')
week = df.groupby([pd.Grouper(key='date_week', freq='W')])['Transaction ID'].count()
df_week = pd.DataFrame({'Week': week.index, 'Count': week.values})
df_week.plot(kind = 'bar', x = 'Week', y = 'Count')
# print(df_week)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Week'] = df['Date'].dt.weekday

# %%
monthly_summary = df.groupby('Month')['Total Amount'].mean()
plt.figure(figsize=(8, 6))
plt.plot(monthly_summary.index, monthly_summary.values, marker='o')
plt.xlabel('Month')
plt.ylabel('Average Total Amount')
plt.title('Seasonal Trends: Average Total Amount per Month')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
for category, group in df.groupby('Product Category'):
    plt.hist(group['Price per Unit'], bins=10, alpha=0.7, label=category)

plt.xlabel('Price per Unit')
plt.ylabel('Frequency')
plt.title('Price Distribution by Product Category')
plt.legend()
plt.show()
